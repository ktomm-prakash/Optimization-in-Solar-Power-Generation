# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\pbari\Downloads\2nd project\dataset2\final_df.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            DATE/TIME  UNIT1-INV1-POWER  UNIT1-INV2-POWER  \
# 0           0  2024-04-01 06:18:00         74.400002         73.099998
# 1           1  2024-04-01 06:19:00         83.500000         81.599998
# 2           2  2024-04-01 06:20:00         88.400002         86.500000
# 3           3  2024-04-01 06:21:00         93.500000         91.400002
# 4           4  2024-04-01 06:22:00         98.500000         96.400002
#
#    UNIT2-INV1-POWER  UNIT2-INV2-POWER  GII  MODULE TEMP.1  RAIN  \
# 0         83.300003         85.199997   25           19.0   0.0
# 1         87.599998         90.099998   27           19.0   0.0
# 2         92.199997         95.000000   29           19.0   0.0
# 3         97.000000        100.099998   31           19.1   0.0
# 4        101.900002        105.000000   33           19.1   0.0
#
#    AMBIENT TEMPRETURE
# 0           22.700001
# 1           22.700001
# 2           22.700001
# 3           22.700001
# 4           22.600000

# %%
df.describe()
# Out:
#          Unnamed: 0  UNIT1-INV1-POWER  UNIT1-INV2-POWER  UNIT2-INV1-POWER  \
# count  68451.000000      68451.000000      68451.000000      68451.000000
# mean   34225.000000       1340.951597       1297.372135       1312.799576
# std    19760.245975        921.759884        906.241368        906.769449
# min        0.000000          0.000000          0.000000          0.000000
# 25%    17112.500000        462.700012        440.700012        452.500000
# 50%    34225.000000       1257.400024       1221.000000       1223.199951
# 75%    51337.500000       2272.449951       2197.200074       2202.550049
# max    68450.000000       2739.800049       2717.399902       2842.199951
#
#        UNIT2-INV2-POWER           GII  MODULE TEMP.1          RAIN  \
# count      68451.000000  68451.000000   68451.000000  68451.000000
# mean        1362.973501    437.589327      42.099571      0.000590
# std          934.900499    307.389013      12.183708      0.027935
# min            0.000000      0.000000       0.000000      0.000000
# 25%          474.299988    147.000000      32.599998      0.000000
# 50%         1278.099976    399.000000      42.500000      0.000000
# 75%         2298.300049    741.000000      52.700001      0.000000
# max         2887.000000   1234.000000      65.400002      4.400000
#
#        AMBIENT TEMPRETURE
# count        68451.000000
# mean            34.427394
# std              5.557231
# min              0.000000
# 25%             30.000000
# 50%             35.099998
# 75%             39.099998
# max             47.599998

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'DATE/TIME', 'UNIT1-INV1-POWER', 'UNIT1-INV2-POWER',
#        'UNIT2-INV1-POWER', 'UNIT2-INV2-POWER', 'GII', 'MODULE TEMP.1', 'RAIN',
#        'AMBIENT TEMPRETURE'],
#       dtype='object')

# %% [markdown]
# # UNIT1-INV1-POWER

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['UNIT1-INV1-POWER'].mean()
print(mean)
# Out:
# 1340.9515974275178

# %%
# Median

# %%
median = df['UNIT1-INV1-POWER'].median()
print(median)
# Out:
# 1257.400024

# %%
# Mode

# %%
mode = df['UNIT1-INV1-POWER'].mode()
print(mode)
# Out:
# 0    0.0
# Name: UNIT1-INV1-POWER, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
UNIT1_INV1_POWER_variance = df['UNIT1-INV1-POWER'].var()
print("Variance of UNIT1-INV1-POWER:", UNIT1_INV1_POWER_variance)
# Out:
# Variance of UNIT1-INV1-POWER: 849641.2840263371

# %%
# Standard

# %%
UNIT1_INV1_POWER_stddev = df['UNIT1-INV1-POWER'].std()
print("Standard Deviation of UNIT1-INV1-POWER:", UNIT1_INV1_POWER_stddev)
# Out:
# Standard Deviation of UNIT1-INV1-POWER: 921.7598841489779

# %%
# Range

# %%
UNIT1_INV1_POWER_range = df['UNIT1-INV1-POWER'].max() - df['UNIT1-INV1-POWER'].min()
print("Range of UNIT1-INV1-POWER):", UNIT1_INV1_POWER_range)
# Out:
# Range of UNIT1-INV1-POWER): 2739.800049

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['UNIT1-INV1-POWER'].skew()
print(skewness)
# Out:
# 0.09537941359303326

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['UNIT1-INV1-POWER'].kurtosis()
print(kurtosis)
# Out:
# -1.4619436135371104

# %% [markdown]
# # UNIT1-INV2-POWER

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['UNIT1-INV2-POWER'].mean()
print(mean)
# Out:
# 1297.372134759726

# %%
# Median

# %%
median = df['UNIT1-INV2-POWER'].median()
print(median)
# Out:
# 1221.0

# %%
# Mode

# %%
mode = df['UNIT1-INV2-POWER'].mode()
print(mode)
# Out:
# 0    0.0
# Name: UNIT1-INV2-POWER, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
UNIT1_INV2_POWER_variance = df['UNIT1-INV2-POWER'].var()
print("Variance of UNIT1-INV2-POWER:", UNIT1_INV2_POWER_variance)
# Out:
# Variance of UNIT1-INV2-POWER: 821273.4165547362

# %%
# Standard

# %%
UNIT1_INV2_POWER_stddev = df['UNIT1-INV2-POWER'].std()
print("Standard Deviation of UNIT1-INV2-POWER:", UNIT1_INV2_POWER_stddev)
# Out:
# Standard Deviation of UNIT1-INV2-POWER: 906.2413677132247

# %%
# Range

# %%
UNIT1_INV2_POWER_range = df['UNIT1-INV2-POWER'].max() - df['UNIT1-INV2-POWER'].min()
print("Range of UNIT1-INV2-POWER):", UNIT1_INV2_POWER_range)
# Out:
# Range of UNIT1-INV2-POWER): 2717.399902

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['UNIT1-INV2-POWER'].skew()
print(skewness)
# Out:
# 0.1015221300227095

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['UNIT1-INV2-POWER'].kurtosis()
print(kurtosis)
# Out:
# -1.4389360226528434

# %% [markdown]
# # UNIT2-INV1-POWER

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['UNIT2-INV1-POWER'].mean()
print(mean)
# Out:
# 1312.7995762990458

# %%
# Median

# %%
median = df['UNIT2-INV1-POWER'].median()
print(median)
# Out:
# 1223.199951

# %%
# Mode

# %%
mode = df['UNIT2-INV1-POWER'].mode()
print(mode)
# Out:
# 0    0.0
# Name: UNIT2-INV1-POWER, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
UNIT2_INV1_POWER_variance = df['UNIT2-INV1-POWER'].var()
print("Variance of UNIT2-INV1-POWER:", UNIT2_INV1_POWER_variance)
# Out:
# Variance of UNIT2-INV1-POWER: 822230.8338578709

# %%
# Standard

# %%
UNIT2_INV1_POWER_stddev = df['UNIT2-INV1-POWER'].std()
print("Standard Deviation of UNIT2-INV1-POWER:", UNIT2_INV1_POWER_stddev)
# Out:
# Standard Deviation of UNIT2-INV1-POWER: 906.7694491202661

# %%
# Range

# %%
UNIT2_INV1_POWER_range = df['UNIT2-INV1-POWER'].max() - df['UNIT2-INV1-POWER'].min()
print("Range of UNIT2-INV1-POWER):", UNIT2_INV1_POWER_range)
# Out:
# Range of UNIT2-INV1-POWER): 2842.199951

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['UNIT2-INV1-POWER'].skew()
print(skewness)
# Out:
# 0.13396891540496064

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['UNIT2-INV1-POWER'].kurtosis()
print(kurtosis)
# Out:
# -1.4250510658613575

# %% [markdown]
# # UNIT2-INV2-POWER

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['UNIT2-INV2-POWER'].mean()
print(mean)
# Out:
# 1362.9735006815824

# %%
# Median

# %%
median = df['UNIT2-INV2-POWER'].median()
print(median)
# Out:
# 1278.099976

# %%
# Mode

# %%
mode = df['UNIT2-INV2-POWER'].mode()
print(mode)
# Out:
# 0    0.0
# Name: UNIT2-INV2-POWER, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
UNIT2_INV2_POWER_variance = df['UNIT2-INV2-POWER'].var()
print("Variance of UNIT2-INV2-POWER:", UNIT2_INV2_POWER_variance)
# Out:
# Variance of UNIT2-INV2-POWER: 874038.9426036271

# %%
# Standard

# %%
UNIT2_INV2_POWER_stddev = df['UNIT2-INV2-POWER'].std()
print("Standard Deviation of UNIT2-INV2-POWER:", UNIT2_INV2_POWER_stddev)
# Out:
# Standard Deviation of UNIT2-INV2-POWER: 934.9004987717287

# %%
# Range

# %%
UNIT2_INV2_POWER_range = df['UNIT2-INV2-POWER'].max() - df['UNIT2-INV2-POWER'].min()
print("Range of UNIT2-INV2-POWER):", UNIT2_INV2_POWER_range)
# Out:
# Range of UNIT2-INV2-POWER): 2887.0

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['UNIT2-INV2-POWER'].skew()
print(skewness)
# Out:
# 0.10934786376910641

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['UNIT2-INV2-POWER'].kurtosis()
print(kurtosis)
# Out:
# -1.4490701291943953

# %% [markdown]
# # GII

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['GII'].mean()
print(mean)
# Out:
# 437.5893266716337

# %%
# Median

# %%
median = df['GII'].median()
print(median)
# Out:
# 399.0

# %%
# Mode

# %%
mode = df['GII'].mode()
print(mode)
# Out:
# 0    2
# Name: GII, dtype: int64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
GII_variance = df['GII'].var()
print("Variance of GII:", GII_variance)
# Out:
# Variance of GII: 94488.00561814733

# %%
# Standard

# %%
GII_stddev = df['GII'].std()
print("Standard Deviation of GII:", GII_stddev)
# Out:
# Standard Deviation of GII: 307.389013496168

# %%
# Range

# %%
GII_range = df['GII'].max() - df['GII'].min()
print("Range of GII):", GII_range)
# Out:
# Range of GII): 1234

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['GII'].skew()
print(skewness)
# Out:
# 0.172632624390072

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['GII'].kurtosis()
print(kurtosis)
# Out:
# -1.3956768397995776

# %% [markdown]
# # MODULE TEMP.1

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['MODULE TEMP.1'].mean()
print(mean)
# Out:
# 42.099571185574256

# %%
# Median

# %%
median = df['MODULE TEMP.1'].median()
print(median)
# Out:
# 42.5

# %%
# Mode

# %%
mode = df['MODULE TEMP.1'].mode()
print(mode)
# Out:
# 0    0.0
# Name: MODULE TEMP.1, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
MODULE_TEMP_1_variance = df['MODULE TEMP.1'].var()
print("Variance of MODULE TEMP.1:", MODULE_TEMP_1_variance)
# Out:
# Variance of MODULE TEMP.1: 148.4427456558239

# %%
# Standard

# %%
MODULE_TEMP_1_stddev = df['MODULE TEMP.1'].std()
print("Standard Deviation of MODULE TEMP.1:", MODULE_TEMP_1_stddev)
# Out:
# Standard Deviation of MODULE TEMP.1: 12.183708206282022

# %%
# Range

# %%
MODULE_TEMP_1_range = df['MODULE TEMP.1'].max() - df['MODULE TEMP.1'].min()
print("Range of MODULE TEMP.1):", MODULE_TEMP_1_range)
# Out:
# Range of MODULE TEMP.1): 65.400002

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['MODULE TEMP.1'].skew()
print(skewness)
# Out:
# -0.4031596461055497

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['MODULE TEMP.1'].kurtosis()
print(kurtosis)
# Out:
# -0.1328818991332188

# %% [markdown]
# # RAIN

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['RAIN'].mean()
print(mean)
# Out:
# 0.0005902334495872563

# %%
# Median

# %%
median = df['RAIN'].median()
print(median)
# Out:
# 0.0

# %%
# Mode

# %%
mode = df['RAIN'].mode()
print(mode)
# Out:
# 0    0.0
# Name: RAIN, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
RAIN_variance = df['RAIN'].var()
print("Variance of RAIN:", RAIN_variance)
# Out:
# Variance of RAIN: 0.0007803675329616491

# %%
# Standard

# %%
RAIN_stddev = df['RAIN'].std()
print("Standard Deviation of RAIN:", RAIN_stddev)
# Out:
# Standard Deviation of RAIN: 0.027935059208128575

# %%
# Range

# %%
RAIN_range = df['RAIN'].max() - df['RAIN'].min()
print("Range of RAIN):", RAIN_range)
# Out:
# Range of RAIN): 4.400000000000001

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['RAIN'].skew()
print(skewness)
# Out:
# 110.16755124239364

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['RAIN'].kurtosis()
print(kurtosis)
# Out:
# 14599.53572137529

# %% [markdown]
# # AMBIENT TEMPRETURE

# %% [markdown]
# First Moment Business Decision (Mean, Median, Mode)

# %%
# Mean

# %%
mean = df['AMBIENT TEMPRETURE'].mean()
print(mean)
# Out:
# 34.42739440467409

# %%
# Median

# %%
median = df['AMBIENT TEMPRETURE'].median()
print(median)
# Out:
# 35.099998

# %%
# Mode

# %%
mode = df['AMBIENT TEMPRETURE'].mode()
print(mode)
# Out:
# 0    39.0
# Name: AMBIENT TEMPRETURE, dtype: float64

# %% [markdown]
# Second Moment Business Decision (Variance, Standard, Range)

# %%
# Variance

# %%
AMBIENT_TEMPRETURE_variance = df['AMBIENT TEMPRETURE'].var()
print("Variance of AMBIENT TEMPRETURE:", AMBIENT_TEMPRETURE_variance)
# Out:
# Variance of AMBIENT TEMPRETURE: 30.882815785314556

# %%
# Standard

# %%
AMBIENT_TEMPRETURE_stddev = df['AMBIENT TEMPRETURE'].std()
print("Standard Deviation of AMBIENT TEMPRETURE:", AMBIENT_TEMPRETURE_stddev)
# Out:
# Standard Deviation of AMBIENT TEMPRETURE: 5.557230945832155

# %%
# Range

# %%
AMBIENT_TEMPRETURE_range = df['AMBIENT TEMPRETURE'].max() - df['AMBIENT TEMPRETURE'].min()
print("Range of AMBIENT TEMPRETURE):", AMBIENT_TEMPRETURE_range)
# Out:
# Range of AMBIENT TEMPRETURE): 47.599998

# %% [markdown]
# Third Moment Business Decision (Skewness)

# %%
# skewness

# %%
skewness = df['AMBIENT TEMPRETURE'].skew()
print(skewness)
# Out:
# -0.24645640454576995

# %% [markdown]
# Fourth Moment Business Decision (Kurtosis)

# %%
# Kurtosis

# %%
kurtosis = df['AMBIENT TEMPRETURE'].kurtosis()
print(kurtosis)
# Out:
# -0.7910726034733324

# %% [markdown]
# # Graphical Representation

# %%
# Histplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns you want to plot
columns = ['UNIT1-INV1-POWER', 'UNIT1-INV2-POWER', 'UNIT2-INV1-POWER', 'UNIT2-INV2-POWER', 'GII', 'MODULE TEMP.1', 'RAIN', 'AMBIENT TEMPRETURE']

# Set up the figure size
plt.figure(figsize=(10, 8))

# Loop through each column to plot both histogram and KDE
for i, col in enumerate(columns):
    plt.subplot(4, 2, i+1)  # Adjust subplot grid based on the number of columns
    sns.histplot(df[col], bins=20, kde=True)  # kde=True adds the Kernel Density Estimate
    plt.title(col)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Boxplot

# %%
df.plot(kind="box",sharey=False,sharex=False,subplots=True,figsize=(20,40),layout=[10,2],vert=0)
plt.subplots_adjust(wspace=0.75)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'DATE/TIME', 'UNIT1-INV1-POWER', 'UNIT1-INV2-POWER',
#        'UNIT2-INV1-POWER', 'UNIT2-INV2-POWER', 'GII', 'MODULE TEMP.1', 'RAIN',
#        'AMBIENT TEMPRETURE'],
#       dtype='object')

# %%
# Calculate the correlation
correlation = df[['UNIT1-INV1-POWER', 'UNIT1-INV2-POWER']].corr().iloc[0, 1]

# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

# Creating scatter plot
sns.scatterplot(data=df, x='UNIT1-INV1-POWER', y='UNIT1-INV2-POWER')

# Adding correlation text
plt.text(
    x=0.1, y=0.9, 
    s=f'Correlation: {correlation:.2f}', 
    transform=plt.gca().transAxes,  # Place text relative to the axes
    fontsize=12, color='red'
)

# Adding labels and title
plt.title('UNIT1-INV1-POWER vs UNIT1-INV2-POWER')
plt.xlabel('UNIT1-INV1-POWER')
plt.ylabel('UNIT1-INV2-POWER')

# Displaying the plot
plt.show()

# %%
# UNIT2-INV1-POWER & UNIT2-INV2-POWER

# %%
# Calculate the correlation
correlation = df[['UNIT2-INV1-POWER', 'UNIT2-INV2-POWER']].corr().iloc[0, 1]

# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

# Creating scatter plot
sns.scatterplot(data=df, x='UNIT2-INV1-POWER', y='UNIT2-INV2-POWER')

# Adding correlation text
plt.text(
    x=0.1, y=0.9, 
    s=f'Correlation: {correlation:.2f}', 
    transform=plt.gca().transAxes,  # Place text relative to the axes
    fontsize=12, color='red'
)

# Adding labels and title
plt.title('UNIT2-INV1-POWER vs UNIT2-INV2-POWER')
plt.xlabel('UNIT2-INV1-POWER')
plt.ylabel('UNIT2-INV2-POWER')

# Displaying the plot
plt.show()

# %%
# GII & MODULE TEMP.1

# %%
# Calculate the correlation
correlation = df[['GII', 'MODULE TEMP.1']].corr().iloc[0, 1]

# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

# Creating scatter plot
sns.scatterplot(data=df, x='GII', y='MODULE TEMP.1')

# Adding correlation text
plt.text(
    x=0.1, y=0.9, 
    s=f'Correlation: {correlation:.2f}', 
    transform=plt.gca().transAxes,  # Place text relative to the axes
    fontsize=12, color='red'
)

# Adding labels and title
plt.title('GII vs MODULE TEMP.1')
plt.xlabel('GII')
plt.ylabel('MODULE TEMP.1')

# Displaying the plot
plt.show()

# %%
# RAIN & AMBIENT TEMPRETURE

# %%
# Calculate the correlation
correlation = df[['RAIN', 'AMBIENT TEMPRETURE']].corr().iloc[0, 1]
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

# Creating scatter plot
sns.scatterplot(data=df, x='RAIN', y='AMBIENT TEMPRETURE')

# Adding correlation text
plt.text(
    x=0.1, y=0.9, 
    s=f'Correlation: {correlation:.2f}', 
    transform=plt.gca().transAxes,  # Place text relative to the axes
    fontsize=12, color='red'
)

# Adding labels and title
plt.title('RAIN vs AMBIENT TEMPRETURE')
plt.xlabel('RAIN')
plt.ylabel('AMBIENT TEMPRETURE')

# Displaying the plot
plt.show()

# %%
# Assuming 'gdf' is your original DataFrame
numerical_columns = df.select_dtypes(exclude=['object']).columns

# Create a new DataFrame with only numerical columns
numerical_df = df[numerical_columns]

# Display the new DataFrame
print(numerical_df)
# Out:
#        Unnamed: 0  UNIT1-INV1-POWER  UNIT1-INV2-POWER  UNIT2-INV1-POWER  \
# 0               0         74.400002         73.099998         83.300003
# 1               1         83.500000         81.599998         87.599998
# 2               2         88.400002         86.500000         92.199997
# 3               3         93.500000         91.400002         97.000000
# 4               4         98.500000         96.400002        101.900002
# ...           ...               ...               ...               ...
# 68446       68446          0.000000          0.000000         21.000000
# 68447       68447          0.000000          0.000000         20.100000
# 68448       68448          0.000000          0.000000         18.900000
# 68449       68449          0.000000          0.000000         17.600000
# 68450       68450          0.000000          0.000000         16.200001
#
#        UNIT2-INV2-POWER  GII  MODULE TEMP.1  RAIN  AMBIENT TEMPRETURE
# 0             85.199997   25           19.0   0.0           22.700001
# 1             90.099998   27           19.0   0.0           22.700001
# 2             95.000000   29           19.0   0.0           22.700001
# 3            100.099998   31           19.1   0.0           22.700001
# 4            105.000000   33           19.1   0.0           22.600000
# ...                 ...  ...            ...   ...                 ...
# 68446         19.700001    3           23.6   0.0           25.500000
# 68447         18.700001    3           23.6   0.0           25.400000
# 68448         17.400000    3           23.5   0.0           25.400000
# 68449         16.000000    3           23.5   0.0           25.400000
# 68450         14.600000    2           23.4   0.0           25.299999
#
# [68451 rows x 9 columns]

# %%
correlation_matrix = numerical_df.corr()

plt.figure(figsize=(10, 8))  
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap for Numerical Data", fontsize=16)
plt.show()
